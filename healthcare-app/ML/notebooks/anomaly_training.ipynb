# %% [markdown]
# # ANOMALY DETECTION MODEL

# %%
import sys
import os

# Add project root to path
project_root = os.path.abspath("..")  # Go one level up from notebooks/
sys.path.append(project_root)
sys.path.append(os.path.abspath(".."))

print("Path added successfully")
# Out:
# Path added successfully

# %% [markdown]
# # Import Modules

# %%
import numpy as np
from sklearn.model_selection import train_test_split
import joblib
import os

from src.preprocessing import generate_synthetic_data, scale_data
from src.autoencoder_model import build_autoencoder
from src.isolation_model import train_isolation_forest

# %% [markdown]
# # Generate Synthetic Data

# %%
data = generate_synthetic_data(5000)
scaled_data = scale_data(data)

# %% [markdown]
# # Train/Test Split

# %%
X_train, X_test = train_test_split(
    scaled_data,
    test_size=0.2,
    random_state=42
)

# %% [markdown]
# # Train Isolation Forest

# %%
iso_model = train_isolation_forest(X_train)

# %% [markdown]
# # Train Autoencoder

# %%
autoencoder = build_autoencoder(X_train.shape[1])

autoencoder.fit(
    X_train,
    X_train,
    epochs=30,
    batch_size=32,
    validation_split=0.1,
    verbose=1
)
# Out:
# Epoch 1/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.8035 - val_loss: 0.5016
# Epoch 2/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3877 - val_loss: 0.2394
# Epoch 3/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1701 - val_loss: 0.1076
# Epoch 4/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0912 - val_loss: 0.0784
# Epoch 5/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0688 - val_loss: 0.0631
# Epoch 6/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0552 - val_loss: 0.0499
# Epoch 7/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0420 - val_loss: 0.0342
# Epoch 8/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0256 - val_loss: 0.0181
# Epoch 9/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0146 - val_loss: 0.0123
# Epoch 10/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0106 - val_loss: 0.0096
# Epoch 11/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0086 - val_loss: 0.0081
# ...

# %% [markdown]
# # Compute Threshold & Save

# %%
reconstructions = autoencoder.predict(X_test)
mse = np.mean(np.power(X_test - reconstructions, 2), axis=1)

threshold = np.percentile(mse, 95)


print("Training complete.")
print("Threshold:", threshold)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training complete.
# Threshold: 0.0005114823278659716

# %% [markdown]
# # SAVING MODELS

# %%
import os
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: c:\Users\lokes\Documents\AI-Healthcare-Anomaly-System\ml\notebooks
